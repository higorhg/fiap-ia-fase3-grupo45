# %% [markdown]
# # FarmTech Solutions — Parte 2: Análise Descritiva
# ## FIAP IA 2026/1 | Fase 3 Cap 10 | Grupo 45
#
# **Responsável:** Higor | **Branch:** `parte2-higor`
#
# ---
# Esta parte cobre correlação entre variáveis, boxplots de NPK por cultura, scatter temperatura x umidade e os principais achados do dataset.

# %% [markdown]
# ## Setup (copie do Parte 1 ou execute aqui)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

sns.set_theme(style='whitegrid', palette='husl')
plt.rcParams['figure.dpi'] = 100

df = pd.read_csv('../produtos_agricolas.csv')
print(f"Dataset carregado: {df.shape[0]} linhas, {df['label'].nunique()} culturas")
df.head()

# %% [markdown]
# ## 1. Gráfico 3 — Correlação entre Variáveis

# %%
features = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']
# TODO: Criar um heatmap de correlação entre as variáveis numéricas
# Dica: df[features].corr() + sns.heatmap(..., annot=True)

# %% [markdown]
# ## 2. Gráfico 4 — Níveis de NPK por Cultura

# %%
# TODO: Criar boxplots de N, P e K para pelo menos 8 culturas à sua escolha
# Dica: use sns.boxplot(data=df_filtrado, x='label', y='N') em subplots 1x3

# %% [markdown]
# ## 3. Gráfico 5 — Temperatura vs. Umidade

# %%
# TODO: Scatter plot temperatura x umidade, colorido por cultura
# Dica: use df.groupby('label') e ax.scatter() para cada grupo

# %% [markdown]
# ## 4. Análise Descritiva — Principais Achados

# %%
# TODO: Calcular médias por cultura e mostrar as 10 culturas com maior N
medias = df.groupby('label')[features].mean().round(2)
# Exibir e comentar os resultados

# %% [markdown]
# ## 5. Narrativa dos Achados
#
# > Escreva aqui (em markdown) os principais padrões encontrados:
# > - Quais variáveis têm maior correlação entre si?
# > - Quais culturas têm perfis mais diferentes das demais?
# > - O que os boxplots de NPK revelam sobre exigência do solo?
