# %% [markdown]
# # FarmTech Solutions — Parte 3: Perfil Ideal das Culturas
# ## FIAP IA 2026/1 | Fase 3 Cap 10 | Grupo 45
#
# **Responsável:** Ceguin | **Branch:** `parte3-ceguin`
#
# ---
# Esta parte define o "perfil ideal" de solo e clima usando as medianas do dataset, e compara **3 culturas à sua escolha** com esse perfil.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

sns.set_theme(style='whitegrid', palette='husl')
plt.rcParams['figure.dpi'] = 100

df = pd.read_csv('../produtos_agricolas.csv')
print(f"Dataset carregado: {df.shape[0]} linhas, {df['label'].nunique()} culturas")
df.head()

# %% [markdown]
# ## 1. Calculando o Perfil Ideal

# %%
features = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']

# TODO: Calcular a mediana de cada variável no dataset completo
# Isso representa o "perfil ideal" — o centro de todas as culturas
perfil_ideal = df[features].median()
print("Perfil ideal:")
print(perfil_ideal)

# %% [markdown]
# ## 2. Escolha suas 3 Culturas

# %%
# TODO: Escolha 3 culturas e justifique a escolha (em markdown abaixo)
# Exemplos: 'rice', 'cotton', 'apple', 'banana', 'coffee', 'maize', 'grapes'
culturas_escolhidas = ['???', '???', '???']  # Substitua aqui

perfis = df[df['label'].isin(culturas_escolhidas)].groupby('label')[features].mean()
perfis.loc['perfil_ideal'] = perfil_ideal
print(perfis.round(2))

# %% [markdown]
# ### Por que essas 3 culturas?
#
# > Explique aqui por que escolheu essas culturas.
# > Por exemplo: diversidade de biomas, relevância pro agronegócio brasileiro, etc.

# %% [markdown]
# ## 3. Gráfico 6 — Comparação Visual das 3 Culturas vs. Perfil Ideal

# %%
# TODO: Criar gráfico de barras comparando as 3 culturas + perfil_ideal
# Mostre pelo menos 3 variáveis diferentes (ex: N, temperature, humidity)
# Dica: subplots 1x3, uma variável por subplot, cores diferentes por cultura

# %% [markdown]
# ## 4. Análise Comparativa
#
# > Para cada cultura escolhida, responda em markdown:
# > - Em quais variáveis ela está acima do perfil ideal?
# > - Em quais está abaixo?
# > - O que isso diz sobre os requisitos dessa cultura?
